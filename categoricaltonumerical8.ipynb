# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visadata=pd.read_csv("/Users/shashankreddy/Desktop/Datafiles/Visadataset - Visadataset.csv")

# %%
visadata.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visadata.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visadata.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
visadata.select_dtypes(include=object)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %% [markdown]
# - categorical to numerical
#
# - it is very important to convert categorical to  nurerical because understands only numbers
#
# - we have different types of methods to convert categorical data to numerical data
#
#       - 1)Map method
#
#       - 2)np.where
#
#       - 3)One hot Encoder
#
#       - 4)Label Encoder

# %%
visadata["case_status"]
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %%
visadata["case_status"].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %% [markdown]
# # MAP METHOD

# %% [markdown]
# - First get the unique labels for each column
#
# - create a dictionary by provididng values to each unique label
#
# - In this example for visadata["case_status"] we have 2 values Certified and Denied
#
# - we need to assign alphabetically
#
# - Certified=0
#
# - Denied=1

# %% [markdown]
# # create dictionary as below`

# %%
d={"Certified":1,"Denied":0}

# %%
type(d)
# Out:
# dict

# %%
visadata["case_status"].map(d)
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: case_status, Length: 25480, dtype: int64

# %%
visadata["case_status_new"]=visadata["case_status"].map(d)

# %%
visadata
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visadata.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status', 'case_status_new'],
#       dtype='object')

# %% [markdown]
# # has_job_experience

# %%
visadata["has_job_experience"].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
d2={"N":0,"Y":1}

# %%
visadata["has_job_experience"].map(d2)
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: has_job_experience, Length: 25480, dtype: int64

# %%
visadata["has_job_experience"]=visadata["has_job_experience"].map(d2)

# %%
visadata
# Out:
#          case_id continent education_of_employee  has_job_experience  \
# 0         EZYV01      Asia           High School                   0
# 1         EZYV02      Asia              Master's                   1
# 2         EZYV03      Asia            Bachelor's                   0
# 3         EZYV04      Asia            Bachelor's                   0
# 4         EZYV05    Africa              Master's                   1
# ...          ...       ...                   ...                 ...
# 25475  EZYV25476      Asia            Bachelor's                   1
# 25476  EZYV25477      Asia           High School                   1
# 25477  EZYV25478      Asia              Master's                   1
# 25478  EZYV25479      Asia              Master's                   1
# 25479  EZYV25480      Asia            Bachelor's                   1
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
type(visadata["case_status_new"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Doing all at once

# %%
visadata=pd.read_csv("/Users/shashankreddy/Desktop/Datafiles/Visadataset - Visadataset.csv")

# %%
lenofcatcols=visadata.columns

# %%
lenofcatcols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
colcat=visadata.select_dtypes(include="object").columns

# %%
colcat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(colcat)
# Out:
# pandas.core.frame.DataFrame

# %%
colcat["case_id"]
# Out:
# 0           EZYV01
# 1           EZYV02
# 2           EZYV03
# 3           EZYV04
# 4           EZYV05
#            ...
# 25475    EZYV25476
# 25476    EZYV25477
# 25477    EZYV25478
# 25478    EZYV25479
# 25479    EZYV25480
# Name: case_id, Length: 25480, dtype: object

# %%
for i in colcat:
    labels=list(visadata[i].unique())
    values= [i for i in range(len(labels))]
    d=dict(zip(labels,values))
    visadata[i]=visadata[i].map(d)
visadata
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# - Above step explanation:
#
# - First get the object elements
#
# - Then for each object element get the number of unique fields
#
# - convert that to list for iteration
#
# - assign values to each field
#
# - then create a dictionary

# %% [markdown]
# # LAbel encoder

# %% [markdown]
# - label encodeer is a package under scikit learn
#
# - Scikit learn package is heart of machine learning
#
# - In scikit learn package we have a method called PreProcessing
#
# - In preprocessing we have LableEncoder

# %% [markdown]
# # any scikit package we have 3 steps

# %% [markdown]
# - step 1 Read the package
#
# - step 2 Save the package
#
# - step 3 Apply Fit transform

# %%
visadata=pd.read_csv("/Users/shashankreddy/Desktop/Datafiles/Visadataset - Visadataset.csv")

# %%
#read the package
from sklearn.preprocessing import LabelEncoder

# %%
#save package
#create an objct for Label Encoder
le=LabelEncoder()

# %%
#apply fit transform
visadata["case_status"]=le.fit_transform(visadata["case_status"])

# %%
visadata
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visadata["education_of_employee"]=le.fit_transform(visadata["education_of_employee"])

# %%
visadata
# Out:
#          case_id continent  education_of_employee has_job_experience  \
# 0         EZYV01      Asia                      2                  N
# 1         EZYV02      Asia                      3                  Y
# 2         EZYV03      Asia                      0                  N
# 3         EZYV04      Asia                      0                  N
# 4         EZYV05    Africa                      3                  Y
# ...          ...       ...                    ...                ...
# 25475  EZYV25476      Asia                      0                  Y
# 25476  EZYV25477      Asia                      2                  Y
# 25477  EZYV25478      Asia                      3                  Y
# 25478  EZYV25479      Asia                      3                  Y
# 25479  EZYV25480      Asia                      0                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # doing for all columns using Label encoder

# %%
visadata=pd.read_csv("/Users/shashankreddy/Desktop/Datafiles/Visadataset - Visadataset.csv")
catcols=visadata.select_dtypes(include='object').columns

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in catcols:
    visadata[i]=le.fit_transform(visadata[i])
visadata
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# # le.inverse_transform

# %%
visadata=pd.read_csv("/Users/shashankreddy/Desktop/Datafiles/Visadataset - Visadataset.csv")
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visadata["case_status"]=le.fit_transform(visadata["case_status"])
print(visadata["case_status"].values)
print(le.inverse_transform(visadata["case_status"]))
# Out:
# [1 0 1 ... 0 0 0]
# ['Denied' 'Certified' 'Denied' ... 'Certified' 'Certified' 'Certified']

# %%
visadata=pd.read_csv("/Users/shashankreddy/Desktop/Datafiles/Visadataset - Visadataset.csv")
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visadata["case_status"]=le.fit_transform(visadata["case_status"])
#if we dont provide values we will get series but we need data in array format
print(visadata["case_status"])
print(le.inverse_transform(visadata["case_status"]))
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64
# ['Denied' 'Certified' 'Denied' ... 'Certified' 'Certified' 'Certified']

# %% [markdown]
# # np.where method

# %% [markdown]
# - np where is applicable only for binary values
#
# - it atkes three arguments
#
# - condition,true value,false value

# %%
visadata=pd.read_csv("/Users/shashankreddy/Desktop/Datafiles/Visadataset - Visadataset.csv")
con=visadata["case_status"]=="Certified"
visadata["case_status"]=np.where(con,0,1)

# %%
visadata["case_status"]
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %% [markdown]
# # one hot Encoder

# %% [markdown]
# - If one is on means another is off
#
# - on represented with 1
#
# - off represented with 0
#
# - if we apply one got encoder on case-status it will create two extra columns called
#
#        - case status denied
#
#        -case status certified

# %% [markdown]
# - When data is idependent there is 90 degree difference between them thay are perpendicular to each other
#
# - machine learning model excepts data to be independent
#
# - perpendiculat to each other

# %% [markdown]
# # pd.get_dummies

# %% [markdown]
# - read the data
#
# - choose one column
#
# - apply pd.get_dummies

# %%
visadata=pd.read_csv("/Users/shashankreddy/Desktop/Datafiles/Visadataset - Visadataset.csv")
data=visadata["case_status"]
pd.get_dummies(data,dtype=int)
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
visadata=pd.read_csv("/Users/shashankreddy/Desktop/Datafiles/Visadataset - Visadataset.csv")
for i in catcols:
   print(pd.get_dummies(visadata[i]))
# Out:
#        EZYV01  EZYV02  EZYV03  EZYV04  EZYV05  EZYV06  EZYV07  EZYV08  EZYV09  \
# 0        True   False   False   False   False   False   False   False   False
# 1       False    True   False   False   False   False   False   False   False
# 2       False   False    True   False   False   False   False   False   False
# 3       False   False   False    True   False   False   False   False   False
# 4       False   False   False   False    True   False   False   False   False
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 25475   False   False   False   False   False   False   False   False   False
# 25476   False   False   False   False   False   False   False   False   False
# 25477   False   False   False   False   False   False   False   False   False
# 25478   False   False   False   False   False   False   False   False   False
# 25479   False   False   False   False   False   False   False   False   False
#
# ...

# %%
visadata
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - in general we prefer label encoder
#
# - We prefer One hot encoder when categorical data has less unique values
