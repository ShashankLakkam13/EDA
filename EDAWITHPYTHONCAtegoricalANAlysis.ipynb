# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Tdata=pd.read_csv("/Users/shashankreddy/Desktop/Datafiles/Titanic Dataset - Titanic Dataset.csv")

# %%
Tdata
# Out:
#          sex   age  sibsp  parch     fare embarked  class    who  alone  \
# 0        NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 1       male  22.0    1.0    0.0   7.2500        S  Third    man  False
# 2        NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 3     female  38.0    1.0    0.0  71.2833        C  First  woman  False
# 4        NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# ...      ...   ...    ...    ...      ...      ...    ...    ...    ...
# 1777  female   NaN    1.0    2.0  23.4500        S  Third  woman  False
# 1778     NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 1779    male  26.0    0.0    0.0  30.0000        C  First    man   True
# 1780     NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 1781    male  32.0    0.0    0.0   7.7500        Q  Third    man   True
#
#       survived
# 0          NaN
# 1          0.0
# 2          NaN
# 3          1.0
# 4          NaN
# ...

# %%
Tdata.isna()
# Out:
#         sex    age  sibsp  parch   fare  embarked  class    who  alone  \
# 0      True   True   True   True   True      True   True   True   True
# 1     False  False  False  False  False     False  False  False  False
# 2      True   True   True   True   True      True   True   True   True
# 3     False  False  False  False  False     False  False  False  False
# 4      True   True   True   True   True      True   True   True   True
# ...     ...    ...    ...    ...    ...       ...    ...    ...    ...
# 1777  False   True  False  False  False     False  False  False  False
# 1778   True   True   True   True   True      True   True   True   True
# 1779  False  False  False  False  False     False  False  False  False
# 1780   True   True   True   True   True      True   True   True   True
# 1781  False  False  False  False  False     False  False  False  False
#
#       survived
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
# ...        ...
# ...

# %%
Tdata.isna().sum()
# Out:
# sex          891
# age         1068
# sibsp        891
# parch        891
# fare         891
# embarked     893
# class        891
# who          891
# alone        891
# survived     891
# dtype: int64

# %%
refinedtdata=Tdata.drop_duplicates()

# %%
refinedtdata
# Out:
#          sex   age  sibsp  parch     fare embarked  class    who  alone  \
# 0        NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 1       male  22.0    1.0    0.0   7.2500        S  Third    man  False
# 3     female  38.0    1.0    0.0  71.2833        C  First  woman  False
# 5     female  26.0    0.0    0.0   7.9250        S  Third  woman   True
# 7     female  35.0    1.0    0.0  53.1000        S  First  woman  False
# ...      ...   ...    ...    ...      ...      ...    ...    ...    ...
# 1771  female  39.0    0.0    5.0  29.1250        Q  Third  woman  False
# 1775  female  19.0    0.0    0.0  30.0000        S  First  woman   True
# 1777  female   NaN    1.0    2.0  23.4500        S  Third  woman  False
# 1779    male  26.0    0.0    0.0  30.0000        C  First    man   True
# 1781    male  32.0    0.0    0.0   7.7500        Q  Third    man   True
#
#       survived
# 0          NaN
# 1          0.0
# 3          1.0
# 5          1.0
# 7          1.0
# ...

# %%
refinedtdata.isnull()
# Out:
#         sex    age  sibsp  parch   fare  embarked  class    who  alone  \
# 0      True   True   True   True   True      True   True   True   True
# 1     False  False  False  False  False     False  False  False  False
# 3     False  False  False  False  False     False  False  False  False
# 5     False  False  False  False  False     False  False  False  False
# 7     False  False  False  False  False     False  False  False  False
# ...     ...    ...    ...    ...    ...       ...    ...    ...    ...
# 1771  False  False  False  False  False     False  False  False  False
# 1775  False  False  False  False  False     False  False  False  False
# 1777  False   True  False  False  False     False  False  False  False
# 1779  False  False  False  False  False     False  False  False  False
# 1781  False  False  False  False  False     False  False  False  False
#
#       survived
# 0         True
# 1        False
# 3        False
# 5        False
# 7        False
# ...        ...
# ...

# %%
refinedtdata.isna()
# Out:
#         sex    age  sibsp  parch   fare  embarked  class    who  alone  \
# 0      True   True   True   True   True      True   True   True   True
# 1     False  False  False  False  False     False  False  False  False
# 3     False  False  False  False  False     False  False  False  False
# 5     False  False  False  False  False     False  False  False  False
# 7     False  False  False  False  False     False  False  False  False
# ...     ...    ...    ...    ...    ...       ...    ...    ...    ...
# 1771  False  False  False  False  False     False  False  False  False
# 1775  False  False  False  False  False     False  False  False  False
# 1777  False   True  False  False  False     False  False  False  False
# 1779  False  False  False  False  False     False  False  False  False
# 1781  False  False  False  False  False     False  False  False  False
#
#       survived
# 0         True
# 1        False
# 3        False
# 5        False
# 7        False
# ...        ...
# ...

# %%
r1=refinedtdata.drop(index=0)

# %%
r1
# Out:
#          sex   age  sibsp  parch     fare embarked  class    who  alone  \
# 1       male  22.0    1.0    0.0   7.2500        S  Third    man  False
# 3     female  38.0    1.0    0.0  71.2833        C  First  woman  False
# 5     female  26.0    0.0    0.0   7.9250        S  Third  woman   True
# 7     female  35.0    1.0    0.0  53.1000        S  First  woman  False
# 9       male  35.0    0.0    0.0   8.0500        S  Third    man   True
# ...      ...   ...    ...    ...      ...      ...    ...    ...    ...
# 1771  female  39.0    0.0    5.0  29.1250        Q  Third  woman  False
# 1775  female  19.0    0.0    0.0  30.0000        S  First  woman   True
# 1777  female   NaN    1.0    2.0  23.4500        S  Third  woman  False
# 1779    male  26.0    0.0    0.0  30.0000        C  First    man   True
# 1781    male  32.0    0.0    0.0   7.7500        Q  Third    man   True
#
#       survived
# 1          0.0
# 3          1.0
# 5          1.0
# 7          1.0
# 9          0.0
# ...

# %%
r1.isnull()
# Out:
#         sex    age  sibsp  parch   fare  embarked  class    who  alone  \
# 1     False  False  False  False  False     False  False  False  False
# 3     False  False  False  False  False     False  False  False  False
# 5     False  False  False  False  False     False  False  False  False
# 7     False  False  False  False  False     False  False  False  False
# 9     False  False  False  False  False     False  False  False  False
# ...     ...    ...    ...    ...    ...       ...    ...    ...    ...
# 1771  False  False  False  False  False     False  False  False  False
# 1775  False  False  False  False  False     False  False  False  False
# 1777  False   True  False  False  False     False  False  False  False
# 1779  False  False  False  False  False     False  False  False  False
# 1781  False  False  False  False  False     False  False  False  False
#
#       survived
# 1        False
# 3        False
# 5        False
# 7        False
# 9        False
# ...        ...
# ...

# %%
r1.isna()
# Out:
#         sex    age  sibsp  parch   fare  embarked  class    who  alone  \
# 1     False  False  False  False  False     False  False  False  False
# 3     False  False  False  False  False     False  False  False  False
# 5     False  False  False  False  False     False  False  False  False
# 7     False  False  False  False  False     False  False  False  False
# 9     False  False  False  False  False     False  False  False  False
# ...     ...    ...    ...    ...    ...       ...    ...    ...    ...
# 1771  False  False  False  False  False     False  False  False  False
# 1775  False  False  False  False  False     False  False  False  False
# 1777  False   True  False  False  False     False  False  False  False
# 1779  False  False  False  False  False     False  False  False  False
# 1781  False  False  False  False  False     False  False  False  False
#
#       survived
# 1        False
# 3        False
# 5        False
# 7        False
# 9        False
# ...        ...
# ...

# %% [markdown]
# # Loc

# %%
r1.iloc[1:6,1:4]
# Out:
#      age  sibsp  parch
# 3   38.0    1.0    0.0
# 5   26.0    0.0    0.0
# 7   35.0    1.0    0.0
# 9   35.0    0.0    0.0
# 11   NaN    0.0    0.0

# %% [markdown]
# # ILOC

# %%
r1.loc[[5,7,9],["sex","age","parch"]]
# Out:
#       sex   age  parch
# 5  female  26.0    0.0
# 7  female  35.0    0.0
# 9    male  35.0    0.0

# %%
cdf=r1["sex"].value_counts()

# %%
cdf
# Out:
# sex
# male      488
# female    292
# Name: count, dtype: int64

# %%
cdf.keys()
# Out:
# Index(['male', 'female'], dtype='object', name='sex')

# %%
cdf.values
# Out:
# array([488, 292])

# %%
cdf.index
# Out:
# Index(['male', 'female'], dtype='object', name='sex')

# %%
import matplotlib.pyplot as plt

# %%
count=cdf.values

# %%
cdf.plot(kind="bar")
plt.show()

# %%
ax=cdf.plot(kind="bar")
ax.bar_label(ax.containers[0])
plt.show()

# %%
rfdata=r1["sex"].value_counts(normalize=True)

# %%
rfdata
# Out:
# sex
# male      0.625641
# female    0.374359
# Name: proportion, dtype: float64

# %%
keys=rfdata.keys()
keys
# Out:
# Index(['male', 'female'], dtype='object', name='sex')

# %%
values=rfdata.values
values
# Out:
# array([0.62564103, 0.37435897])

# %%
plt.pie(x=values,labels=keys,autopct="%0.3f%%")
plt.show()
